# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import clientserver # import from our script

client = clientserver.Client() # Create a client instance

#client.call() # start the call and print echo

while True: # Loop forever
    print("Which command would you like to run?")
    print("1. Search for a number")
    print("2. Get all numbers")
    print("3. Exit the application")	
    
    choice = input("Enter your choice: ") # Get the user's choice
    
    if choice == "1": # If the user chose 1
        client.get()
    elif choice == "2": # If the user chose 2
        client.getall()
    elif choice == "3":
        print("Exiting the application")
        break
    else: # If the user chose anything else
        print("Invalid choice. Please try again.") # Print an error message
# Out:
# 2024-10-31 14:19:33,106 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=57, family=AddressFamily.AF_INET, type=SocketKind.SOCK_STREAM, proto=0, laddr=('127.0.0.1', 44838), raddr=('127.0.0.1', 50007)>
# Which command would you like to run?
# 1. Search for a number
# 2. Get all numbers
# 3. Exit the application
# Enter your choice:  1
# Enter name:  Björn
# 2024-10-31 14:19:38,081 - vs2lab.a1_layers.clientserver.Client - INFO - Client sent: Björn
# 2024-10-31 14:19:38,084 - vs2lab.a1_layers.clientserver.Client - INFO - Client received: b'123-456-7890'
# 123-456-7890
#
# Which command would you like to run?
# 1. Search for a number
# 2. Get all numbers
# 3. Exit the application
# Enter your choice:  1
# Enter name:  Björn
# 2024-10-31 14:21:11,625 - vs2lab.a1_layers.clientserver.Client - INFO - Client sent: Björn
# 2024-10-31 14:21:11,664 - vs2lab.a1_layers.clientserver.Client - INFO - Client received: b'123-456-7890'
# 123-456-7890
#
# Which command would you like to run?
# 1. Search for a number
# 2. Get all numbers
# 3. Exit the application

# %% [markdown]
# Finished.
